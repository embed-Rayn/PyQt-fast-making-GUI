# %% [markdown]
# ## 02.05 Display - QLabel

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5 import uic

form_class = uic.loadUiType("labelTest.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)
        
        #라벨기본 텍스트 설정
        self.label.setText("LABEL")
        #버튼에 기능을 할당하는 코드
        self.chTxt.clicked.connect(self.changeTextFunction)
        self.printTxt.clicked.connect(self.printTextFunction)

    def changeTextFunction(self) :
        #self.Label이름.setText("String")
        #Label에 글자를 바꾸는 메서드
        self.label.setText("This is Label - Change Text")

    def printTextFunction(self) :
        #self.Label이름.text()
        #Label에 있는 글자를 가져오는 메서드
        print(self.label.text())

if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass()
    myWindow.show()
    app.exec_()
# Out:
# This is Label - Change Text
# This is Label - Change Text

# %% [markdown]
# ### Slots
# - def clear ()
#
# - def setMovie (movie)
#
# - def setNum (arg__1)
#
# - def setNum (arg__1)
#
# - def setPicture (arg__1)
#
# - def setPixmap (arg__1)
#
# - def setText (arg__1)
#
# ### Signals
# - def linkActivated (link)
#
# - def linkHovered (link)

# %% [markdown]
# ### Functions
# - def alignment ()
# - def buddy ()
# - def hasScaledContents ()
# - def hasSelectedText ()
# - def indent ()
# - def margin ()
# - def movie ()
# - def openExternalLinks ()
# - def picture ()
# - def pixmap ()
# - def selectedText ()
# - def selectionStart ()
# - def setAlignment (arg__1)
# - def setBuddy (arg__1)
# - def setIndent (arg__1)
# - def setMargin (arg__1)
# - def setOpenExternalLinks (open)
# - def setScaledContents (arg__1)
# - def setSelection (arg__1, arg__2)
# - def setTextFormat (arg__1)
# - def setTextInteractionFlags (flags)
# - def setWordWrap (on)
# - def text ()
# - def textFormat ()
# - def textInteractionFlags ()
# - def wordWrap ()

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5 import uic
from PyQt5.QtGui import QMovie
form_class = uic.loadUiType("labelfunc.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)
        
        print("label1의 alignment는",self.label.alignment())
        self.label.setText("alignment")
        #self.label.setAlignment(2)
        #https://doc.qt.io/archives/4.3/qt.html#AlignmentFlag-enum
        self.label_2.setText("hasScaledContents, hasSelectedText")

        self.label_3.setIndent(5)
        self.label_3.setMargin(4)
        self.label_3.setText("indent, margin")
        print("label3의 들여쓰기", self.label_3.indent())
        print("label3의 마진", self.label_3.margin())

        gif = QMovie("testgif.gif")
        #self.label_4.setText("movie")
        self.label_4.setMovie(gif)
        print("label4의 무비(gif)",self.label_4.movie())
        
        #self.label_5.setOpenExternalLinks(True)
        self.label_5.setText("OpenExternalLinks")
        #print(self.label_5.OpenExternalLinks)
        #####################################################################

        self.label_6.setText("picture")
        #self.label_6.setPicture()
        
        self.label_7.setText("pixmap")
        self.label_8.setText("selectedText")
        self.label_9.setText("selectionStart")
        # returns the index of the first selected character in the label or -1 if no text is selected.
        # int
        self.label_10.setWordWrap(True)
        self.label_10.setText("WordWrapWordWrapWordWrapWordWrap")
        print(self.label_10.wordWrap())
        #긴 단어 처리 방법 정하는 속성

        #####################################################################
        self.label_11.setText("TextInteractionFlags")
        self.label_12.setText("text")
        self.label_13.setText("LABEL")
        self.label_14.setText("LABEL")
        self.label_15.setText("LABEL")

if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass()
    myWindow.show()
    app.exec_()
# Out:
# ...
# 5
# 4
# None

# %% [markdown]
# ### 02.06 Display - QTextBrowser

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5 import uic

form_class = uic.loadUiType("textbrowserTest.ui")[0]

class WindowClass(QMainWindow, form_class) :
    def __init__(self) :
        super().__init__()
        self.setupUi(self)

        self.btn_print.setText("Print Text")
        self.btn_set_text.setText("set Text")
        self.btn_append_txt.setText("Apeend Text")
        self.btn_clear.setText("Clear")
        #버튼에 기능을 할당하는 코드
        self.btn_print.clicked.connect(self.printTextFunction)
        self.btn_set_text.clicked.connect(self.changeTextFunction)
        self.btn_append_txt.clicked.connect(self.appendTextFunction)
        self.btn_clear.clicked.connect(self.clearTextFunction)

    def printTextFunction(self) :
        #self.Textbrowser이름.toPlainText()
        #Textbrowser에 있는 글자를 가져오는 메서드
        print(self.textBrowser.toPlainText())

    def changeTextFunction(self) :
        #self.Textbrowser이름.setPlainText()
        #Textbrowser에 있는 글자를 가져오는 메서드
        self.textBrowser.setPlainText("This is Textbrowser - Change Text")

    def appendTextFunction(self) :
        #self.Textbrowser이름.append()
        #Textbrowser에 있는 글자를 가져오는 메서드
        self.textBrowser.append("Append Text")

    def clearTextFunction(self) :
        #self.Textbrowser.clear()
        #Textbrowser에 있는 글자를 지우는 메서드
        self.textBrowser.clear()

if __name__ == "__main__" :
    app = QApplication(sys.argv)
    myWindow = WindowClass()
    myWindow.show()
    app.exec_()
# Out:
# This is Textbrowser - Change Text
# Append Text
# Append Text
# This is Textbrowser - Change Text
# Append Text
#
# Append Text
# Append Text

# %% [markdown]
# ### Functions
# - def backwardHistoryCount ()
# - def clearHistory ()
# - def doSetSource (name[, type=QTextDocument.UnknownResource])
# - def forwardHistoryCount ()
# - def historyTitle (arg__1)
# - def historyUrl (arg__1)
# - def isBackwardAvailable ()
# - def isForwardAvailable ()
# - def openExternalLinks ()
# - def openLinks ()
# - def searchPaths ()
# - def setOpenExternalLinks (open)
# - def setOpenLinks (open)
# - def setSearchPaths (paths)
# - def source ()
# - def sourceType ()
#
# ### Virtual functions
# - def backward ()
# - def forward ()
# - def home ()
# - def reload ()
# - def setSource (name)
#
# ### Slots
# - def setSource (name, type)
#
# ### Signals
# - def anchorClicked (arg__1)
# - def backwardAvailable (arg__1)
# - def forwardAvailable (arg__1)
# - def highlighted (arg__1)
# - def highlighted (arg__1)
# - def historyChanged ()
# - def sourceChanged (arg__1)
